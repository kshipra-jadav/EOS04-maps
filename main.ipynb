# %%
from pathlib import Path
from pprint import pp

import folium
from geopy import Point

from utils import *

BASE_DIR = Path.home() / "work" / "major" / "SAR Data" / "Map Test Data" / "E04_SAR_MRS_19JUN2025_170130832927_18468_STUC00ZTD_25091_5_DH_A_R_N23740_E072155"

product_xml = BASE_DIR / "product.xml"
base_meta = BASE_DIR / "BAND_META.txt"

coords = get_coords(base_meta)

coords
# Out:
# {'center': Point(23.608492, 72.234425, 0.0),
#  'upper_left': Point(24.188497, 71.352555, 0.0),
#  'upper_right': Point(24.438392, 72.837366, 0.0),
#  'lower_left': Point(22.769538, 71.647387, 0.0),
#  'lower_right': Point(23.018946, 73.108987, 0.0)}

# %%
ul, ur, lr, ll = coords['upper_left'], coords['upper_right'], coords['lower_right'], coords['lower_left']
center = coords['center']
locations = [
    [ul.latitude, ul.longitude],
    [ur.latitude, ur.longitude],
    [lr.latitude, lr.longitude],
    [ll.latitude, ll.longitude],
    [ul.latitude, ul.longitude]
]

m = folium.Map(location=[center.latitude, center.longitude], zoom_start=9, zoom_control=False, scrollWheelZoom=False, dragging=False)

kw = {
    "color": "blue",
    "line_cap": "round",
    "fill": False,
    "weight": 5,
}

folium.Polygon(
    locations=locations,
    line_join="mitter",
    dash_array="5, 10",
    **kw
).add_to(m)

folium.Marker(
    location=[center.latitude, center.longitude],
    popup="This is the center!",
    tooltip="This is center",
    icon=folium.Icon(icon="cloud", color="red")
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13fc5a5fe5731b2500cdb3c4b775c494 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13fc5a5fe5731b2500cdb3c4b775c494&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13fc5a5fe5731b2500cdb3c4b775c494 = L.map(
#                 &quot;map_13fc5a5fe5731b2500cdb3c4b775c494&quot;,
#                 {
#                     center: [23.608492, 72.234425],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: false,
#   &quot;preferCanvas&quot;: false,
#   &quot;scrollWheelZoom&quot;: false,
#   &quot;dragging&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e81d40bf17f717a43eaab3a570443ac9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e81d40bf17f717a43eaab3a570443ac9.addTo(map_13fc5a5fe5731b2500cdb3c4b775c494);
#
#
#             var polygon_e7d2651b0d86128f6775aabeda22cad0 = L.polygon(
#                 [[24.188497, 71.352555], [24.438392, 72.837366], [23.018946, 73.108987], [22.769538, 71.647387], [24.188497, 71.352555]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;mitter&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_13fc5a5fe5731b2500cdb3c4b775c494);
#
#
#             var marker_d29d3f3e06ef8bb73cfff2defc00bc44 = L.marker(
#                 [23.608492, 72.234425],
#                 {
# }
#             ).addTo(map_13fc5a5fe5731b2500cdb3c4b775c494);
#
#
#             var icon_3f00f460626f09b7cda49dcf3576722f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_073189fba0dfa5e342444fb98e7083bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_102c58eedd185663fc28e504f08b788c = $(`&lt;div id=&quot;html_102c58eedd185663fc28e504f08b788c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;This is the center!&lt;/div&gt;`)[0];
#                 popup_073189fba0dfa5e342444fb98e7083bf.setContent(html_102c58eedd185663fc28e504f08b788c);
#
#
#
#         marker_d29d3f3e06ef8bb73cfff2defc00bc44.bindPopup(popup_073189fba0dfa5e342444fb98e7083bf)
#         ;
#
#
#
#
#             marker_d29d3f3e06ef8bb73cfff2defc00bc44.bindTooltip(
#                 `&lt;div&gt;
#                      This is center
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_d29d3f3e06ef8bb73cfff2defc00bc44.setIcon(icon_3f00f460626f09b7cda49dcf3576722f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
user_point = Point(23.2156, 72.6369)

bbox = get_bounding_box_coordinates(user_point, 25)

print(bbox)
# Out:
# {'upper_left': Point(23.441144715539558, 72.39224879951736, 0.0), 'lower_right': Point(22.98966947961121, 72.88073038697917, 0.0)}

# %%
ul, lr = bbox['upper_left'], bbox['lower_right']
bounds = [
    [ul.latitude, ul.longitude],
    [lr.latitude, lr.longitude]
]

kw = {
    "color": "red",
    "line_cap": "round",
    "fill": True,
    "fill_color": "red",
    "weight": 5,
}

folium.Rectangle(
    bounds=bounds,
    line_join="mitter",
    popup="bbox",
    **kw
).add_to(m)

folium.Marker(
    location=[user_point.latitude, user_point.longitude],
    popup="User Point",
    tooltip="User Point",
    
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13fc5a5fe5731b2500cdb3c4b775c494 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13fc5a5fe5731b2500cdb3c4b775c494&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13fc5a5fe5731b2500cdb3c4b775c494 = L.map(
#                 &quot;map_13fc5a5fe5731b2500cdb3c4b775c494&quot;,
#                 {
#                     center: [23.608492, 72.234425],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: false,
#   &quot;preferCanvas&quot;: false,
#   &quot;scrollWheelZoom&quot;: false,
#   &quot;dragging&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e81d40bf17f717a43eaab3a570443ac9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e81d40bf17f717a43eaab3a570443ac9.addTo(map_13fc5a5fe5731b2500cdb3c4b775c494);
#
#
#             var polygon_e7d2651b0d86128f6775aabeda22cad0 = L.polygon(
#                 [[24.188497, 71.352555], [24.438392, 72.837366], [23.018946, 73.108987], [22.769538, 71.647387], [24.188497, 71.352555]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;mitter&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_13fc5a5fe5731b2500cdb3c4b775c494);
#
#
#             var marker_d29d3f3e06ef8bb73cfff2defc00bc44 = L.marker(
#                 [23.608492, 72.234425],
#                 {
# }
#             ).addTo(map_13fc5a5fe5731b2500cdb3c4b775c494);
#
#
#             var icon_3f00f460626f09b7cda49dcf3576722f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_073189fba0dfa5e342444fb98e7083bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_102c58eedd185663fc28e504f08b788c = $(`&lt;div id=&quot;html_102c58eedd185663fc28e504f08b788c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;This is the center!&lt;/div&gt;`)[0];
#                 popup_073189fba0dfa5e342444fb98e7083bf.setContent(html_102c58eedd185663fc28e504f08b788c);
#
#
#
#         marker_d29d3f3e06ef8bb73cfff2defc00bc44.bindPopup(popup_073189fba0dfa5e342444fb98e7083bf)
#         ;
#
#
#
#
#             marker_d29d3f3e06ef8bb73cfff2defc00bc44.bindTooltip(
#                 `&lt;div&gt;
#                      This is center
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_d29d3f3e06ef8bb73cfff2defc00bc44.setIcon(icon_3f00f460626f09b7cda49dcf3576722f);
#
#
#             tile_layer_e81d40bf17f717a43eaab3a570443ac9.addTo(map_13fc5a5fe5731b2500cdb3c4b775c494);
#
#
#                 marker_d29d3f3e06ef8bb73cfff2defc00bc44.setIcon(icon_3f00f460626f09b7cda49dcf3576722f);
#
#
#             var rectangle_81f20866ccf3a0f37b70a3d2ff23186a = L.rectangle(
#                 [[23.441144715539558, 72.39224879951736], [22.98966947961121, 72.88073038697917]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;mitter&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_13fc5a5fe5731b2500cdb3c4b775c494);
#
#
#         var popup_91c045c4d8d5846b2651807f586a1331 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50a736e766a16f54d0422937c37b0a06 = $(`&lt;div id=&quot;html_50a736e766a16f54d0422937c37b0a06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;bbox&lt;/div&gt;`)[0];
#                 popup_91c045c4d8d5846b2651807f586a1331.setContent(html_50a736e766a16f54d0422937c37b0a06);
#
#
#
#         rectangle_81f20866ccf3a0f37b70a3d2ff2
