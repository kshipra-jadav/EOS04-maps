# %%
import os
import glob
from pathlib import Path
from pprint import pp

import folium

from utils import *

BASE_DIR = Path.home() / "work" / "major" / "SAR Data" / "Level 2 Data EOS04"

product_xml = BASE_DIR / "product.xml"
base_meta = BASE_DIR / "BAND_META.txt"

corners = get_coords_from_xml(product_xml)
center = get_scene_center(base_meta)

# %%
ul = [corners['UpperLeftCorner'].latitude, corners['UpperLeftCorner'].longitude]
lr = [corners['LowerRightCorner'].latitude, corners['LowerRightCorner'].longitude]

m = folium.Map(location=[center.latitude, center.longitude], zoom_start=9, zoom_control=False, dragging=False, scrollWheelZoom=False)

kw = {
    "color": "blue",
    "line_cap": "round",
    "fill": False,
    "weight": 5,
}

folium.Rectangle(
    bounds=[ul, lr],
    line_join="mitter",
    dash_array="5, 10",
    **kw
).add_to(m)

folium.Marker(
    location=[center.latitude, center.longitude],
    popup="This is the center!",
    tooltip="This is tooltip",
    icon=folium.Icon(icon="cloud", color="red")
).add_to(m)

# %%
bbox = get_bounding_box_coordinates(center, 50)

print(bbox)
# Out:
# {'upper_left': Point(22.890561769870995, 73.08219042237715, 0.0), 'lower_right': Point(21.987547814054594, 74.05366007596051, 0.0)}

# %%
ul, lr = bbox['upper_left'], bbox['lower_right']
bounds = [
    [ul.latitude, ul.longitude],
    [lr.latitude, lr.longitude]
]

kw = {
    "color": "red",
    "line_cap": "round",
    "fill": True,
    "fill_color": "red",
    "weight": 5,
}

folium.Rectangle(
    bounds=bounds,
    line_join="mitter",
    popup="bbox",
    **kw
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
