# %%
import os
import glob
from pathlib import Path
from pprint import pp

import folium

from utils import *

BASE_DIR = Path.home() / "work" / "major" / "SAR Data" / "Level 2 Data EOS04"

product_xml = BASE_DIR / "product.xml"
base_meta = BASE_DIR / "BAND_META.txt"

coords = get_coords_from_xml(product_xml)
center_lat, center_long = get_scene_center(base_meta)

# %%
ul = [coords['UpperLeftCorner']['lat'], coords['UpperLeftCorner']['long']]
lr = [coords['LowerRightCorner']['lat'], coords['LowerRightCorner']['long']]

m = folium.Map(location=[center_lat, center_long], zoom_start=9, zoom_control=False, dragging=False, scrollWheelZoom=False)

kw = {
    "color": "blue",
    "line_cap": "round",
    "fill": True,
    "fill_color": "red",
    "weight": 5,
}

folium.Rectangle(
    bounds=[ul, lr],
    line_join="mitter",
    dash_array="5, 10",
    **kw
).add_to(m)

folium.Marker(
    location=[center_lat, center_long],
    popup="This is the center!",
    tooltip="This is tooltip",
    icon=folium.Icon(icon="cloud", color="red")
).add_to(m)

# %%
bbox = get_bounding_box_coordinates((center_lat, center_long), 50, 50, 50, 50)

print(bbox)

for direction, coords in bbox.items():
    folium.Marker(
        location=coords,
        popup=direction,
        tooltip=direction,
        icon=folium.Icon(icon="info-sign", color='red')
    ).add_to(m)
# Out:
# {'upper_left': (22.890561769870995, 73.08219042237715), 'lower_right': (21.987547814054594, 74.05366007596051)}

# %%
ul_bbox, ur_bbox = bbox['upper_left'], bbox['lower_right']

folium.Rectangle(
    bounds=[ul_bbox, ur_bbox],
    line_join="mitter",
    popup="bbox",
    **kw
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5184d18f6a301a256be0ac7e3c7858c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5184d18f6a301a256be0ac7e3c7858c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5184d18f6a301a256be0ac7e3c7858c1 = L.map(
#                 &quot;map_5184d18f6a301a256be0ac7e3c7858c1&quot;,
#                 {
#                     center: [22.439798, 73.569497],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: false,
#   &quot;preferCanvas&quot;: false,
#   &quot;dragging&quot;: false,
#   &quot;scrollWheelZoom&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08c9c86a87b8e2150bc1331f7492ac59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_08c9c86a87b8e2150bc1331f7492ac59.addTo(map_5184d18f6a301a256be0ac7e3c7858c1);
#
#
#             var rectangle_7b3d5527801e7c8715fc010413965071 = L.rectangle(
#                 [[23.273679, 72.628405], [21.599667, 74.49956]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: &quot;5, 10&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;mitter&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_5184d18f6a301a256be0ac7e3c7858c1);
#
#
#             var marker_5e6e4128c21d907c11d69d8e9a33472b = L.marker(
#                 [22.439798, 73.569497],
#                 {
# }
#             ).addTo(map_5184d18f6a301a256be0ac7e3c7858c1);
#
#
#             var icon_17743cb7dceecdeaa00eca327c0033d6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;cloud&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_318f0491eb358935e72f6b93075c6ce4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5017849ee3030461265ceba18f99ae8 = $(`&lt;div id=&quot;html_a5017849ee3030461265ceba18f99ae8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;This is the center!&lt;/div&gt;`)[0];
#                 popup_318f0491eb358935e72f6b93075c6ce4.setContent(html_a5017849ee3030461265ceba18f99ae8);
#
#
#
#         marker_5e6e4128c21d907c11d69d8e9a33472b.bindPopup(popup_318f0491eb358935e72f6b93075c6ce4)
#         ;
#
#
#
#
#             marker_5e6e4128c21d907c11d69d8e9a33472b.bindTooltip(
#                 `&lt;div&gt;
#                      This is tooltip
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_5e6e4128c21d907c11d69d8e9a33472b.setIcon(icon_17743cb7dceecdeaa00eca327c0033d6);
#
#
#             var marker_631e7629d30c262827e4a8bd7bfb2094 = L.marker(
#                 [22.890561769870995, 73.08219042237715],
#                 {
# }
#             ).addTo(map_5184d18f6a301a256be0ac7e3c7858c1);
#
#
#             var icon_23b94221dddccf666c4eba1bca3580cc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f245c0690022612d2fda43e0ace7e2d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8cb4826113f02759d3765534dff1e60 = $(`&lt;div id=&quot;html_d8cb4826113f02759d3765534dff1e60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;upper_left&lt;/div&gt;`)[0];
#                 popup_f245c0690022612d2fda43e0ace7e2d4.setContent(html_d8cb4826113f02759d3765534dff1e60);
#
#
#
#         marker_631e7629d30c262827e4a8bd7bfb2094.bindPopup(popup_f245c0690022612d2fda43e0ace7e2d4)
#         ;
#
#
#
#
#             marker_631e7629d30c262827e4a8bd7bfb2094.bindTooltip(
#                 `&lt;div&gt;
#                      upper_left
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_631e7629d30c262827e4a8bd7bfb2094.setIcon(icon_23b94221dddccf666c4eba1bca3580cc);
#
#
#             var marker_b46293775b92
